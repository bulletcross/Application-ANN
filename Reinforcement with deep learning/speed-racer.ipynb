# %%
import gym
import universe
env = gym.make('flashgames.DriftRunners2-v0')
env.configure(remotes=1)
observation_n = env.reset()
while True:
 action_n = [[('KeyEvent', 'ArrowUp', True)] for ob in observation_n]
 observation_n, reward_n, done_n, info = env.step(action_n)
 print ("observation: ", observation_n)
 print ("reward: ", reward_n)
env.render()
# Out:
# [2017-09-03 22:22:06,472] Making new env: flashgames.DriftRunners2-v0
# ---------------------------------------------------------------------------
# DockerException                           Traceback (most recent call last)
# <ipython-input-10-8378e5c9a051> in <module>()
#       2 import universe
#       3 env = gym.make('flashgames.DriftRunners2-v0')
# ----> 4 env.configure(remotes=1)
#       5 observation_n = env.reset()
#       6 while True:
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in configure(self, *args, **kwargs)
#     222
#     223         try:
# --> 224             self._configure(*args, **kwargs)
#     225         except TypeError as e:
#     226             # It can be confusing if you have the wrong environment
#
# /usr/local/lib/python2.7/dist-packages/universe/vectorized/core.pyc in _configure(self, **kwargs)
#      37
#      38     def _configure(self, **kwargs):
# ---> 39         super(Wrapper, self)._configure(**kwargs)
#      40         assert self.env.n is not None, "Did not set self.env.n: self.n={} self.env={} self={}".format(self.env.n, self.env, self)
#      41         self.n = self.env.n
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in _configure(self, *args, **kwargs)
#     347
#     348     def _configure(self, *args, **kwargs):
# --> 349         return self.env.configure(*args, **kwargs)
#     350
#     351     def _seed(self, seed=None):
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in configure(self, *args, **kwargs)
#     222
#     223         try:
# --> 224             self._configure(*args, **kwargs)
#     225         except TypeError as e:
#     226             # It can be confusing if you have the wrong environment
#
# /usr/local/lib/python2.7/dist-packages/universe/wrappers/render.pyc in _configure(self, **kwargs)
#      16
#      17     def _configure(self, **kwargs):
# ---> 18         super(Render, self)._configure(**kwargs)
#      19         self.metadata = self.metadata.copy()
#      20         modes = self.metadata.setdefault('render.modes', [])
#
# /usr/local/lib/python2.7/dist-packages/universe/vectorized/core.pyc in _configure(self, **kwargs)
#      37
#      38     def _configure(self, **kwargs):
# ---> 39         super(Wrapper, self)._configure(**kwargs)
#      40         assert self.env.n is not None, "Did not set self.env.n: self.n={} self.env={} self={}".format(self.env.n, self.env, self)
#      41         self.n = self.env.n
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in _configure(self, *args, **kwargs)
#     347
#     348     def _configure(self, *args, **kwargs):
# --> 349         return self.env.configure(*args, **kwargs)
#     350
#     351     def _seed(self, seed=None):
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in configure(self, *args, **kwargs)
#     222
#     223         try:
# --> 224             self._configure(*args, **kwargs)
#     225         except TypeError as e:
#     226             # It can be confusing if you have the wrong environment
#
# /usr/local/lib/python2.7/dist-packages/universe/wrappers/throttle.pyc in _configure(self, skip_metadata, fps, **kwargs)
#      25
#      26     def _configure(self, skip_metadata=False, fps='default', **kwargs):
# ---> 27         super(Throttle, self)._configure(**kwargs)
#      28         if fps == 'default':
#      29             fps = self.metadata['video.frames_per_second']
#
# /usr/local/lib/python2.7/dist-packages/universe/vectorized/core.pyc in _configure(self, **kwargs)
#      37
#      38     def _configure(self, **kwargs):
# ---> 39         super(Wrapper, self)._configure(**kwargs)
#      40         assert self.env.n is not None, "Did not set self.env.n: self.n={} self.env={} self={}".format(self.env.n, self.env, self)
#      41         self.n = self.env.n
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in _configure(self, *args, **kwargs)
#     347
#     348     def _configure(self, *args, **kwargs):
# --> 349         return self.env.configure(*args, **kwargs)
#     350
#     351     def _seed(self, seed=None):
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in configure(self, *args, **kwargs)
#     222
#     223         try:
# --> 224             self._configure(*args, **kwargs)
#     225         except TypeError as e:
#     226             # It can be confusing if you have the wrong environment
#
# /usr/local/lib/python2.7/dist-packages/universe/envs/vnc_env.pyc in _configure(self, remotes, client_id, start_timeout, docker_image, ignore_clock_skew, disable_action_probes, vnc_driver, vnc_kwargs, rewarder_driver, replace_on_crash, allocate_sync, observer, api_key, record, sample_env_ids)
#     197             remotes=remotes, runtime=runtime, start_timeout=start_timeout,
#     198             api_key=api_key,
# --> 199             use_recorder_ports=record,
#     200         )
#     201         self.connection_names = [None] * self.n
#
# /usr/local/lib/python2.7/dist-packages/universe/remotes/build.pyc in build(client_id, remotes, runtime, start_timeout, **kwargs)
#      17             start_timeout=start_timeout,
#      18             reuse=kwargs.get('reuse', False),
# ---> 19             n=n,
#      20         ), n
#      21     elif remotes.startswith('vnc://'):
#
# /usr/local/lib/python2.7/dist-packages/universe/remotes/docker_remote.pyc in __init__(self, runtime, n, reuse, start_timeout)
#      42         self.connect_vnc = True
#      43         self.connect_rewarder = True
# ---> 44         self._assigner = PortAssigner(reuse=reuse)
#      45
#      46         self._popped = False
#
# /usr/local/lib/python2.7/dist-packages/universe/remotes/docker_remote.pyc in __init__(self, reuse)
#     160         self.reuse = reuse
#     161         self.instance_id = 'universe-' + random_alphanumeric(length=6)
# --> 162         self.client, self.info = get_client()
#     163         self._next_port = 5900
#     164         self._refresh_ports()
#
# /usr/local/lib/python2.7/dist-packages/universe/remotes/docker_remote.pyc in get_client()
#     154         return docker.Client(base_url=host, tls=tls_config, version=client_api_version), info
#     155     else:
# --> 156         return docker.Client(base_url=host, version=client_api_version), info
#     157
#     158 class PortAssigner(object):
#
# /usr/local/lib/python2.7/dist-packages/docker/client.pyc in __init__(self, base_url, version, timeout, tls, user_agent, num_pools)
#      97         elif isinstance(version, six.string_types):
#      98             if version.lower() == 'auto':
# ---> 99                 self._version = self._retrieve_server_version()
#     100             else:
#     101                 self._version = version
#
# /usr/local/lib/python2.7/dist-packages/docker/client.pyc in _retrieve_server_version(self)
#     122         except Exception as e:
#     123             raise errors.DockerException(
# --> 124                 'Error while fetching server API version: {0}'.format(e)
#     125             )
#     126
#
# DockerException: Error while fetching server API version: ('Connection aborted.', error(13, 'Permission denied'))
